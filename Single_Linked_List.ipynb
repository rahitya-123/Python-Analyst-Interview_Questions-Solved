# %% [markdown]
# ## Single Linked List
#
# In this program , I have created a linked list with the methods of inserting a value at the beginning, at the end, inserting a list of values at the end, inserting a value at a particular index, removing a value at a particular index, finding the length of linked list and finally printing linked list values

# %%
class Node:
    def __init__(self,data = None, next = None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        node = Node(data, self.head)
        self.head = node

    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data, None)
            return

        itr = self.head
        while itr.next:
            itr = itr.next
        itr.next = Node(data, None)

    def insert_values(self, data_list):
        for data in data_list:
            self.insert_at_end(data)


    def insert_at(self, index, data):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.insert_at_beginning(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = Node(data,itr.next)
            break
            itr = itr.next
            count+=1
            

    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index == 0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
                break
            itr = itr.next
            count += 1
            

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count

    def print(self):
        if self.head is None:
            print("Linkedlist is empty")
            return

        itr = self.head
        llstr =''

        while itr:
            llstr += str(itr.data) + ' --> '
            itr = itr.next

        print(llstr)

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_beginning("Badam")
    ll.insert_at_end("Apple")
    ll.insert_at_beginning("kacha")
    ll.insert_values(["banana", "mango", "grapes", "orange"])
    ll.remove_at(2)
    ll.insert_at(0,"figs")
    ll.insert_at(2,"jackfruit")
    #ll.remove_at(20)
    print("length:" , ll.get_length())
    ll.print()
# Out:
# length: 7
# figs --> kacha --> Badam --> banana --> mango --> grapes --> orange -->
